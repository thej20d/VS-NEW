# %%
# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
im = np.zeros((6,8),dtype=np.uint8)
im[2,3]=255
fig, ax = plt.subplots()
ax.imshow(im,cmap= 'gray',vmin=0,vmax=255)
ax.xaxis.tick_top()
plt.show()

# %%
# %matplotlib inline  
import cv2 as cv
import matplotlib.pyplot as plt
imgo = cv.imread('emma.jpg')
imgc = cv.cvtColor(imgo, cv.COLOR_BGR2RGB)
fig, ax = plt.subplots(1,2)
ax[0].imshow(imgo)
ax[0].set_title('Without Color Conversion')
ax[0].axis('off')
ax[1].imshow(imgc)
ax[1].set_title('With Color Conversion')
ax[1].axis('off')
plt.show()

# %% [markdown]
# Displaying with OpencCV's HighGUI

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('emma.jpg',cv.IMREAD_COLOR)
cv.namedWindow('image',cv.WINDOW_AUTOSIZE)
cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Displaying Image Properties

# %%
# %matplotlib inline 
import cv2 as cv
import matplotlib.pyplot as plt 
img = cv.imread('emma.jpg',cv.IMREAD_COLOR)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
fig, ax = plt.subplots()
ax.imshow(img)
ax.axis('off')
plt.show()
print(img.shape)
print(img.dtype)
print(img.size)
# Out:
# (194, 259, 3)
# uint8
# 150738

# %% [markdown]
# Increasing the Brightness

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('emma.jpg',cv.IMREAD_GRAYSCALE)
imgb = img + 100
imgc = cv.add(img,100)
f, ax = plt.subplots(1,3,figsize=(15,15))
ax[0].imshow(img,cmap='gray',vmin=0,vmax=255)
ax[0].set_title('Original Image')
ax[0].axis('off')
ax[1].imshow(imgb,cmap='gray',vmin=0,vmax=255)
ax[1].set_title('Image + 50')
ax[1].axis('off')
ax[2].imshow(imgc,cmap='gray',vmin=0,vmax=255)
ax[2].set_title('cv.add')
ax[2].axis('off')
plt.show()

# %%
# %matplotlib inline
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('emma.jpg',cv.IMREAD_COLOR)
if img is None:
    print('Could not open or find the image')
    assert(False)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Emma')
plt.xticks([]), plt.yticks([])
plt.show()
img[:,:,1:3] = 0
plt.imshow(img)
plt.title('after zeroiing planes')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Intensity Transformation : Identity Transformation Code 1

# %%
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\sande\AppData\Local\Temp\ipykernel_36852\3866612278.py:8: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_xlabel('input ,$f(\mathbf{x})$')
# C:\Users\sande\AppData\Local\Temp\ipykernel_36852\3866612278.py:9: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_ylabel('output,$\\mathrm{T}[f(\mathbf{x})]$')
# (194, 259)

# %%
# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
transform = np.arange(0,256).astype('uint8')
fig,ax = plt.subplots()
ax.plot (transform)
ax.set_xlabel('input ,$f(\mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.savefig('transform identity.png')
plt.show()
img_orig = cv.imread('emma.jpg',cv.IMREAD_GRAYSCALE)
print(img_orig.shape)
cv.namedWindow('image',cv.WINDOW_AUTOSIZE)
cv.imshow('image',img_orig)
cv.waitKey(0)
image_transformed = cv.LUT(img_orig,transform)
cv.imshow('image',image_transformed)

# %% [markdown]
# Identity Transform Using Numpy Indexing

# %%
# identity transform using numpy

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

transform = np.arange(0,256).astype('uint8')
fig,ax = plt.subplots()
ax.plot (transform)
ax.set_xlabel('input ,$f(\mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('emma.jpg',cv.IMREAD_GRAYSCALE)
print(img_orig.shape)
cv.namedWindow('image',cv.WINDOW_AUTOSIZE)
cv.imshow('image',img_orig)
cv.waitKey(0)
image_transformed = transform[img_orig]
cv.imshow('image',image_transformed)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\sande\AppData\Local\Temp\ipykernel_8680\3971453912.py:11: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_xlabel('input ,$f(\mathbf{x})$')
# C:\Users\sande\AppData\Local\Temp\ipykernel_8680\3971453912.py:12: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_ylabel('output,$\\mathrm{T}[f(\mathbf{x})]$')
# (194, 259)

# %% [markdown]
# Negative Transform

# %%
# negative transform

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

transform = np.arange(255,-1,-1).astype('uint8')
print(transform.shape)
fig,ax = plt.subplots()
ax.plot (transform)

ax.set_xlabel('input ,$f(mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('emma.jpg',cv.IMREAD_GRAYSCALE)
cv.namedWindow('image',cv.WINDOW_AUTOSIZE)
cv.imshow('image',img_orig)
cv.waitKey(0)
image_transformed = cv.LUT(img_orig,transform)
cv.imshow('image',image_transformed)
cv.waitKey(0)
cv.destroyAllWindows()
plt.show()
# Out:
# (256,)

# %%
# negative transform

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt


img_orig = cv.imread('emma.jpg',cv.IMREAD_GRAYSCALE)
transform = np.arange(255,0).astype('uint8')
print(transform.shape)
fig,ax = plt.subplots()
ax.plot (transform)

ax.set_xlabel('input ,$f(mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()


image_transformed = cv.LUT(img_orig,transform)

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(img_orig, cmap="gray")
ax[0].set_title("Original")
ax[0].axis("off")
ax[1].imshow(image_transformed, cmap="gray")
ax[1].set_title("Transformed ")
ax[1].axis("off")
plt.show()
# Out:
# (0,)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[50], line 23
#      19 ax.set_aspect('equal')
#      20 plt.show()
# ---> 23 image_transformed = cv.LUT(img_orig,transform)
#      25 fig, ax = plt.subplots(1,2, figsize=(15,15))
#      26 ax[0].imshow(img_orig, cmap="gray")
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\lut.cpp:368: error: (-215:Assertion failed) (lutcn == cn || lutcn == 1) && _lut.total() == 256 && _lut.isContinuous() && (depth == CV_8U || depth == CV_8S) in function 'cv::LUT'

# %% [markdown]
# Intensity Transform : Intensity Windowing 3

# %%
# negative transform

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

transform = np.arange(255,-1,-1).astype('uint8')
print(transform.shape)
fig,ax = plt.subplots()
ax.plot (transform)

ax.set_xlabel('input ,$f(mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
image_transformed = cv.LUT(img_orig,transform)
fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(img_orig, cmap="gray")
ax[0].set_title("Original")
ax[0].axis("off")
ax[1].imshow(image_transformed, cmap="gray")
ax[1].set_title("Transformed ")
ax[1].axis("off")


plt.show()
# Out:
# (256,)

# %%
#Intensity Windowing

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

c= np.array([(175,10),(175,250)])

t1 = np.linspace(c[0,1],c[0,1],c[0,0]+1-0).astype('uint8')
print(len(t1))
t2 = np.linspace(c[0,1]+1,c[1,1],c[1,0]-c[0,0]).astype('uint8')
print(len(t2))  
t3 = np.linspace(c[1,1]+1,250,255-c[1,0]).astype('uint8')
print(len(t3))

transform = np.concatenate((t1,t2),axis=0).astype('uint8')
transform = np.concatenate((transform,t3),axis=0).astype('uint8')
print(len(transform))

fig,ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel('input ,$f(mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('q.jpg',cv.IMREAD_GRAYSCALE)

image_transformed = cv.LUT(img_orig,transform)
fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(img_orig, cmap="gray")
ax[0].set_title("Original")
ax[0].axis("off")
ax[1].imshow(image_transformed, cmap="gray")
ax[1].set_title("Transformed ")
ax[1].axis("off")
plt.show()
# Out:
# 176
# 0
# 80
# 256

# %%
#Intensity Windowing

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

c= np.array([(25,250),(25,10)])

t1 = np.linspace(c[0,1],c[0,1],c[0,0]+1-0).astype('uint8')
print(len(t1))
t2 = np.linspace(c[0,1]+1,c[1,1],c[1,0]-c[0,0]).astype('uint8')
print(len(t2))  
t3 = np.linspace(c[1,1]+1,10,255-c[1,0]).astype('uint8')
print(len(t3))

transform = np.concatenate((t1,t2),axis=0).astype('uint8')
transform = np.concatenate((transform,t3),axis=0).astype('uint8')
print(len(transform))

fig,ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel('input ,$f(mathbf{x})$')
ax.set_ylabel('output,$\\mathrm{T}[f(mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('q.jpg',cv.IMREAD_GRAYSCALE)

image_transformed = cv.LUT(img_orig,transform)

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(img_orig, cmap="gray")
ax[0].set_title("Original")
ax[0].axis("off")
ax[1].imshow(image_transformed, cmap="gray")
ax[1].set_title("Transformed ")
ax[1].axis("off")
plt.show()
# Out:
# 26
# 0
# 230
# 256

# %%
# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#not changed
im = cv.imread('q.jpg',cv.IMREAD_GRAYSCALE)
assert im is not None
c= np.array([(100,50),(150,200)])

t1 = np.linspace(0,c[0,1],c[0,0]+1-0).astype('uint8')
print(len(t1))
t2 = np.linspace(c[0,1]+1,c[1,1],c[1,0]-c[0,0]).astype('uint8')
print(len(t2))  
t3 = np.linspace(c[1,1]+1,255,255-c[1,0]).astype('uint8')
print(len(t3))

transform = np.concatenate((t1,t2),axis=0).astype('uint8')
transform = np.concatenate((transform,t3),axis=0).astype('uint8')
print(len(transform))

fig,ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
ax.grid()
plt.show()

Image_transform = cv.LUT(im, transform)

fig, ax = plt.subplots(1,2, figsize=(15,15))
ax[0].imshow(im, cmap="gray")
ax[0].set_title("Original")
ax[0].axis("off")
ax[1].imshow(Image_transform, cmap="gray")
ax[1].set_title("Transformed ")
ax[1].axis("off")
plt.show()
# Out:
# 101
# 50
# 105
# 256

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig,ax = plt.subplots()
gamma = [0.2,0.5,1,2,5] 
for g in gamma:
    table = np.array([((i/255.0)**g)*255 for i in np.arange(0,256)]).astype('uint8')
    ax.plot(table,label='$\\gamma ={g}$'.format(g=g))
ax.legend(loc = 'best')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
ax.set_xlabel(r'input ,$f(\mathbf{x})$')
ax.set_ylabel(r'output,$\mathrm{T}[f(\mathbf{x})]$')
plt.show()
