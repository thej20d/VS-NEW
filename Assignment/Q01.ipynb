# %%
#Intensity Windowing

# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

c= np.array([(220,170),(220,220)])

t1 = np.linspace(0,c[0,1],c[0,0]+1-0).astype('uint8')
print(len(t1))
t2 = np.linspace(c[0,1]+1,c[1,1],c[1,0]-c[0,0]).astype('uint8')
print(len(t2))  
t3 = np.linspace(c[1,1]+1,240,255-c[1,0]).astype('uint8')
print(len(t3))

transform = np.concatenate((t1,t2),axis=0).astype('uint8')
transform = np.concatenate((transform,t3),axis=0).astype('uint8')
print(len(transform))

fig,ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel('input ,$f(\mathbf{x})$')
ax.set_ylabel('output,$\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

img_orig = cv.imread('q1.jpg',cv.IMREAD_COLOR)
cv.namedWindow('image',cv.WINDOW_AUTOSIZE)
cv.imshow('image',img_orig)
cv.waitKey(0)
image_transformed = cv.LUT(img_orig,transform)
cv.imshow('image',image_transformed)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 221
# 0
# 35
# 256
# <>:23: SyntaxWarning: invalid escape sequence '\m'
# <>:24: SyntaxWarning: invalid escape sequence '\m'
# <>:23: SyntaxWarning: invalid escape sequence '\m'
# <>:24: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\sande\AppData\Local\Temp\ipykernel_26292\3391941837.py:23: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_xlabel('input ,$f(\mathbf{x})$')
# C:\Users\sande\AppData\Local\Temp\ipykernel_26292\3391941837.py:24: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_ylabel('output,$\mathrm{T}[f(\mathbf{x})]$')
